# %%
import pandas as pd

# %%
df = pd.read_csv('../preprocessing/lu7ah_cleand.csv')

# %%
df1 = pd.read_csv('../preprocessing/absher.csv')

# %%
df3 = pd.read_csv('../preprocessing/lohatk_cleaned.csv')

# %%
df3['char_en'] = df3['char_en'].apply(lambda x: ' '.join(x))
df3['plate_no'] = df3['plate_no'].astype('Int64')

# %%
df4 = pd.read_csv('../preprocessing/vip_cleand.csv')

# %%
df5 = pd.read_csv('../preprocessing/mstaml_cleand.csv')

# %%
merged_df = pd.concat([df, df1, df3, df4,df5], ignore_index=True)

# %%
merged_df.head(3)
# Out:
#   char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0  ر هـ م   Z H R        ر       هـ        م        R        H        Z
# 1  ر هـ م   Z H R        ر       هـ        م        R        H        Z
# 2  ر هـ م   Z H R        ر       هـ        م        R        H        Z
#
#    plate_no  price class  Unnamed: 0
# 0      9777   6500   NaN         NaN
# 1      9888   6500   NaN         NaN
# 2      9666   6500   NaN         NaN

# %%
merged_df[merged_df['class'] == 'ذهبي']
# Out:
#     char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 815   د د و   U D D        د        د        و        D        D        U
# 816   ن م ا   A Z N        ن        م        ا        N        Z        A
#
#      plate_no  price class  Unnamed: 0
# 815         2  80000  ذهبي         NaN
# 816         4  65000  ذهبي         NaN

# %%
merged_df.duplicated().sum()
# Out:
# 58

# %%
merged_df[merged_df.duplicated(['char1_ar','char2_ar','char3_ar','char1_en','char2_en','char3_en','plate_no'],keep='first')].sort_values('plate_no')
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 2399          س          S        س      NaN      NaN        S      NaN
# 1080      س م أ      A Z S        س        م        أ        S        Z
# 2622  م   م   ح  J   Z   Z        م        م        ح        Z        Z
# 2980  ى   ح   و  U   J   V        ى        ح        و        V        J
# 3146  س   م   ا  A   Z   S        س        م        ا        S        Z
# ...         ...        ...      ...      ...      ...      ...      ...
# 3519  ب   ق   و  U   G   B        ب        ق        و        B        G
# 644      ر هـ م      Z H R        ر       هـ        م        R        H
# 643      ر هـ م      Z H R        ر       هـ        م        R        H
# 2032  س   ب   ع  E   B   S        س        ب        ع        S        B
# 678       ح أ ر      R A J        ح        أ        ر        J        A
#
#      char3_en  plate_no    price class  Unnamed: 0
# 2399      NaN         0  2500000   NaN         NaN
# ...

# %%
merged_df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
merged_df['char_ar'] = merged_df['char_ar'].str.replace("هـ", "ه", regex=True)

# %%
merged_df['char1_ar'] = merged_df['char1_ar'].str.replace("هـ", "ه", regex=True)

# %%
merged_df['char2_ar'] = merged_df['char2_ar'].str.replace("هـ", "ه", regex=True)

# %%
merged_df['char3_ar'] = merged_df['char3_ar'].str.replace("هـ", "ه", regex=True)

# %%
merged_df['char_ar'] = merged_df['char_ar'].str.replace(" ", "", regex=True)

# %%
merged_df['char_ar'] = merged_df['char_ar'].apply(lambda x: ' '.join(x))

# %%
merged_df['char_en'] = merged_df['char_en'].str.replace(" ", "", regex=True)

# %%
merged_df['char_en'] = merged_df['char_en'].apply(lambda x: ' '.join(x))

# %%
merged_df['char1_ar'][110]
# Out:
# 'ه'

# %%
columns_to_replace = ['char_ar', 'char1_ar', 'char2_ar', 'char3_ar']
merged_df[columns_to_replace] = merged_df[columns_to_replace].apply(lambda x: x.str.replace('ا', 'أ'))

# %%
merged_df.head(2)
# Out:
#   char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0   ر ه م   Z H R        ر        ه        م        R        H        Z
# 1   ر ه م   Z H R        ر        ه        م        R        H        Z
#
#    plate_no  price class
# 0      9777   6500   NaN
# 1      9888   6500   NaN

# %%
merged_df.shape
# Out:
# (3600, 11)

# %%
merged_df[merged_df['char3_ar'].isnull()]
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 1808     ق ر     R G        ق        ر      NaN        G        R      NaN
# 1990       ص       X        ص      NaN      NaN        X      NaN      NaN
# 2177     أ م     Z A        أ        م      NaN        A        Z      NaN
# 2191     ب د     D B        ب        د      NaN        B        D      NaN
# 2226     ح أ     A J        ح        أ      NaN        J        A      NaN
# 2398       س       S        س      NaN      NaN        S      NaN      NaN
# 2399       س       S        س      NaN      NaN        S      NaN      NaN
# 2525       ق       G        ق      NaN      NaN        G      NaN      NaN
# 2955       أ       A        أ      NaN      NaN        A      NaN      NaN
# 3229     ى م     Z V        ى        م      NaN        V        Z      NaN
# 3235     ن ص     X N        ن        ص      NaN        N        X      NaN
# ...

# %%
merged_df.to_csv('mergedData.csv', index=False)
