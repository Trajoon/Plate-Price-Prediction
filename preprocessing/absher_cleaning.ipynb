# %%
import numpy as py
import pandas as pd

# %% [markdown]
# ## Load data

# %%
df1 = pd.read_csv('mazad.csv')

# %%
df2 = pd.read_csv('mazad1.csv')

# %%
df3 = pd.read_csv('mazad2.csv')

# %%
df4 = pd.read_csv('mazad3.csv')

# %% [markdown]
# ## View data

# %%
df1.shape
# Out:
# (70, 11)

# %%
df1.head(2)
# Out:
#    numberofbids plateNumber plateNumberAr  plateNumber 2 plateNumberEn  \
# 0             0           ١         د ب س              1         S B D
# 1            30          ١۰         س ن ص             10         X N S
#
#    simply-amount 2  simply-amount 3  simply-amount 4 highestBidAmount  \
# 0                5               26               19       500,000.00
# 1                5               41               30        17,000.00
#
#    sortAmount  sortIndex
# 0      500000          0
# 1       17000          1

# %%
df2.shape
# Out:
# (35, 9)

# %%
df2.head(2)
# Out:
#   ribbon  numberofbids plateNumber plateNumberAr  plateNumber 2 plateNumberEn  \
# 0   ذهبي             6           ٢         د د و              2         U D D
# 1   ذهبي             3           ٤         ن م ا              4         A Z N
#
#   highestBidAmount  sortAmount  sortIndex
# 0        80,000.00       80000          0
# 1        65,000.00       65000          3

# %%
df3.shape
# Out:
# (70, 11)

# %%
df3.head(2)
# Out:
#    numberofbids plateNumber plateNumberAr  plateNumber 2 plateNumberEn  \
# 0            36          ٢۰         ح ل ه             20         H L J
# 1            24           ۸         ع و ر              8         R U E
#
#    simply-amount 2  simply-amount 3  simply-amount 4 highestBidAmount  \
# 0                1               12               57        21,000.00
# 1                2               52               37        52,000.00
#
#    sortAmount  sortIndex
# 0       19500          0
# 1       52000          1

# %%
df4.shape
# Out:
# (70, 6)

# %%
df4.head(2)
# Out:
#    numberofbids plateNumber plateNumberAr  plateNumber 2 plateNumberEn  \
# 0             3           ١         و ي و              1         U V U
# 1            22        ۸۰۸۰         د ع س           8080         S E D
#
#    sortAmount
# 0      420000
# 1       13000

# %% [markdown]
# ## Proccess

# %% [markdown]
# #### df1 13/3/2025

# %%
df1 = df1[['plateNumberAr','plateNumber 2','plateNumberEn','sortAmount']]

# %%
df2 = df2[['plateNumberAr','plateNumber 2','plateNumberEn','sortAmount','ribbon']]

# %%
df1[['char1_ar', 'char2_ar', 'char3_ar']] = df1['plateNumberAr'].str.split(' ', n=2, expand=True)

# %%
df1[['char3_en', 'char2_en', 'char1_en']] = df1['plateNumberEn'].str.split(' ', n=2, expand=True)

# %%
df1['price'] = df1['sortAmount']

# %%
df1['plate_no'] = df1['plateNumber 2']

# %%
df1['char_ar'] =df1['plateNumberAr']

# %%
df1['char_en'] = df1['plateNumberEn']

# %%
df1 = df1[['char_ar','char_en','char1_ar','char2_ar','char3_ar','char1_en','char2_en','char3_en','plate_no','price']]

# %%
df1
# Out:
#    char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0    د ب س   S B D        د        ب        س        D        B        S
# 1    س ن ص   X N S        س        ن        ص        S        N        X
# 2    ق ح ل   L J G        ق        ح        ل        G        J        L
# 3    ل ب ل   L B L        ل        ب        ل        L        B        L
# 4    أ أ أ   A A A        أ        أ        أ        A        A        A
# ..     ...     ...      ...      ...      ...      ...      ...      ...
# 65   ب ي م   Z V B        ب        ي        م        B        V        Z
# 66   ر ع د   D E R        ر        ع        د        R        E        D
# 67   د ع و   U E D        د        ع        و        D        E        U
# 68   د ع د   D E D        د        ع        د        D        E        D
# 69   أ ح ب   B J A        أ        ح        ب        A        J        B
#
#     plate_no   price
# 0          1  500000
# 1         10   17000
# 2         40   12500
# 3         91   12500
# 4       2116    8000
# ..       ...     ...
# 65      4321   23700
# 66      5955   12000
# 67      8959    1000
# 68      3553    4000
# 69      1225    4900
#
# [70 rows x 10 columns]

# %% [markdown]
# #### df2 13/3/2025

# %%
df2[['char1_ar', 'char2_ar', 'char3_ar']] = df2['plateNumberAr'].str.split(' ', n=2, expand=True)

# %%
df2[['char3_en', 'char2_en', 'char1_en']] = df2['plateNumberEn'].str.split(' ', n=2, expand=True)

# %%
df2['price'] = df2['sortAmount']

# %%
df2['plate_no'] = df2['plateNumber 2']

# %%
df2['char_ar'] =df2['plateNumberAr']

# %%
df2['char_en'] = df2['plateNumberEn']

# %%
df2 = df2[['char_ar','char_en','char1_ar','char2_ar','char3_ar','char1_en','char2_en','char3_en','plate_no','price','ribbon']]

# %%
df2
# Out:
#    char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0    د د و   U D D        د        د        و        D        D        U
# 1    ن م ا   A Z N        ن        م        ا        N        Z        A
# 2   د هـ م   Z H D        د       هـ        م        D        H        Z
# 3    ع ل م   Z L E        ع        ل        م        E        L        Z
# 4    ق م ح   J Z G        ق        م        ح        G        Z        J
# 5    ر و ر   R U R        ر        و        ر        R        U        R
# 6   ر هـ ى   V H R        ر       هـ        ى        R        H        V
# 7    ر و ب   B U R        ر        و        ب        R        U        B
# 8    ر و ا   A U R        ر        و        ا        R        U        A
# 9    ر ن ص   X N R        ر        ن        ص        R        N        X
# 10   ر ن ل   L N R        ر        ن        ل        R        N        L
# 11   د د د   D D D        د        د        د        D        D        D
# 12   د د د   D D D        د        د        د        D        D        D
# 13   د د د   D D D        د        د        د        D        D        D
# 14  ر هـ ع   E H R        ر       هـ        ع        R        H        E
# 15   ر و ص   X U R        ر        و        ص        R        U        X
# 16   ب ب ب   B B B        ب        ب        ب        B        B        B
# 17   ب ب ب   B B B        ب        ب        ب        B        B        B
# 18   ب ب ب   B B B        ب        ب        ب        B        B        B
# 19   ر و د   D U R        ر        و        د        R        U        D
# 20   ر ص ب   B X R        ر        ص        ب        R        X        B
# 21   ر ن ن   N N R        ر        ن        ن        R        N        N
# 22   ح ح ح   J J J        ح        ح        ح        J        J        J
# 23   ح ح ح   J J J        ح        ح        ح        J        J        J
# 24   ح ح ح   J J J        ح        ح        ح        J        J        J
# 25   ر ل ك   K L R        ر        ل        ك        R        L        K
# 26  ر هـ ا   A H R        ر       هـ        ا        R        H        A
# 27   ا ا ا   A A A        ا        ا        ا        A        A        A
# 28   ا ا ا   A A A        ا        ا        ا        A        A        A
# 29   ا ا ا   A A A        ا        ا        ا        A        A        A
# 30  ر هـ ص   X H R        ر       هـ        ص        R        H        X
# 31  ر هـ م   Z H R        ر       هـ        م        R        H        Z
# 32   ر ك ق   G K R        ر        ك        ق        R        K        G
# 33  ر ب هـ   H B R        ر        ب       هـ        R        B        H
# 34   ر م ك   K Z R        ر        م        ك        R        Z        K
#
#     plate_no  price  ribbon
# 0          2  80000    ذهبي
# 1          4  65000    ذهبي
# 2         10  25000  برونزي
# 3         46  26000  برونزي
# 4         88  26000     فضي
# 5       1000  14000  برونزي
# 6       1111  19000     فضي
# 7       2000   7000  برونزي
# 8       2222  15000     فضي
# 9       3000   5000  برونزي
# 10      3333  13000     فضي
# 11      3616   4000  برونزي
# 12      3621   3500  برونزي
# 13      3625   3500  برونزي
# 14      4000   6000  برونزي
# 15      4444  14000     فضي
# 16      4701   4000  برونزي
# 17      4726   3000  برونزي
# 18      4728   3500  برونزي
# 19      5000   9000  برونزي
# 20      5555  13000     فضي
# 21      6000  10000  برونزي
# 22      6504   3500  برونزي
# 23      6513   3500  برونزي
# 24      6520   3000  برونزي
# 25      6666  15000     فضي
# 26      7000  10000  برونزي
# 27      7544   9000  برونزي
# 28      7546   3500  برونزي
# 29      7550   9000  برونزي
# 30      7777  14000     فضي
# 31      8000   9500  برونزي
# 32      8888  14000     فضي
# 33      9000   7000  برونزي
# 34      9999  17000     فضي

# %% [markdown]
# #### df3 16/3/2025

# %%
df3.head(1)
# Out:
#    numberofbids plateNumber plateNumberAr  plateNumber 2 plateNumberEn  \
# 0            36          ٢۰         ح ل ه             20         H L J
#
#    simply-amount 2  simply-amount 3  simply-amount 4 highestBidAmount  \
# 0                1               12               57        21,000.00
#
#    sortAmount  sortIndex
# 0       19500          0

# %%
# Fix the English plate char {ح ل ه} {H L J} - > {J L H}
df3['plateNumberEn'] = df3['plateNumberEn'].apply(lambda x:x[::-1])

# %%
df3[['char1_ar', 'char2_ar', 'char3_ar']] = df3['plateNumberAr'].str.split(' ', n=2, expand=True)

# %%
df3[['char3_en', 'char2_en', 'char1_en']] = df3['plateNumberEn'].str.split(' ', n=2, expand=True)

# %%
df3['price'] = df3['sortAmount']

# %%
df3['plate_no'] = df3['plateNumber 2']

# %%
df3['char_ar'] =df3['plateNumberAr']

# %%
df3['char_en'] = df3['plateNumberEn']

# %%
df3 = df3[['char_ar','char_en','char1_ar','char2_ar','char3_ar','char1_en','char2_en','char3_en','plate_no','price']]

# %%
df3
# Out:
#    char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0    ح ل ه   J L H        ح        ل        ه        H        L        J
# 1    ع و ر   E U R        ع        و        ر        R        U        E
# 2    ي ن م   V N Z        ي        ن        م        Z        N        V
# 3    س د أ   S D A        س        د        أ        A        D        S
# 4    ح ل أ   J L A        ح        ل        أ        A        L        J
# ..     ...     ...      ...      ...      ...      ...      ...      ...
# 65   ر أ ك   R A K        ر        أ        ك        K        A        R
# 66   ر ن أ   R N A        ر        ن        أ        A        N        R
# 67   د س د   D S D        د        س        د        D        S        D
# 68   د م ع   D Z E        د        م        ع        E        Z        D
# 69   ح ص ك   J X K        ح        ص        ك        K        X        J
#
#     plate_no  price
# 0         20  19500
# 1          8  52000
# 2         84   9000
# 3        800   7000
# 4       6464   8500
# ..       ...    ...
# 65      3989   1000
# 66      9798   8500
# 67      2678   1000
# 68      2898   5000
# 69      3899   1000
#
# [70 rows x 10 columns]

# %% [markdown]
# #### df4 16/3/2025

# %%
df4.head(2)
# Out:
#    numberofbids plateNumber plateNumberAr  plateNumber 2 plateNumberEn  \
# 0             3           ١         و ي و              1         U V U
# 1            22        ۸۰۸۰         د ع س           8080         S E D
#
#    sortAmount
# 0      420000
# 1       13000

# %%
df4[['char1_ar', 'char2_ar', 'char3_ar']] = df4['plateNumberAr'].str.split(' ', n=2, expand=True)

# %%
df4[['char3_en', 'char2_en', 'char1_en']] = df4['plateNumberEn'].str.split(' ', n=2, expand=True)

# %%
df4['price'] = df4['sortAmount']

# %%
df4['plate_no'] = df4['plateNumber 2']

# %%
df4['char_ar'] =df4['plateNumberAr']

# %%
df4['char_en'] = df4['plateNumberEn']

# %%
df4 = df4[['char_ar','char_en','char1_ar','char2_ar','char3_ar','char1_en','char2_en','char3_en','plate_no','price']]

# %%
df3.head(2)
# Out:
#   char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0   ح ل ه   J L H        ح        ل        ه        H        L        J
# 1   ع و ر   E U R        ع        و        ر        R        U        E
#
#    plate_no  price
# 0        20  19500
# 1         8  52000

# %%
df4
# Out:
#    char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0    و ي و   U V U        و        ي        و        U        V        U
# 1    د ع س   S E D        د        ع        س        D        E        S
# 2    ه ع ر   R E H        ه        ع        ر        H        E        R
# 3    ق س ل   L S G        ق        س        ل        G        S        L
# 4    س ع د   D E S        س        ع        د        S        E        D
# ..     ...     ...      ...      ...      ...      ...      ...      ...
# 65   ر ه ق   G H R        ر        ه        ق        R        H        G
# 66   ر ر ق   G R R        ر        ر        ق        R        R        G
# 67   ر ن د   D N R        ر        ن        د        R        N        D
# 68   ب أ ي   V A B        ب        أ        ي        B        A        V
# 69   ر ق د   D G R        ر        ق        د        R        G        D
#
#     plate_no   price
# 0          1  420000
# 1       8080   13000
# 2          7   49000
# 3         53    9500
# 4       5011    8500
# ..       ...     ...
# 65      7212    1000
# 66      9799    2800
# 67      1515   16500
# 68      8988    4500
# 69      5862    1000
#
# [70 rows x 10 columns]

# %% [markdown]
# ## Save data

# %%
merged_df = pd.concat([ df1, df2, df3, df4], ignore_index=True)

# %%
merged_df.rename(columns={'ribbon':'class'},inplace=True)

# %%
merged_df['class'].value_counts()
# Out:
# class
# برونزي    23
# فضي       10
# ذهبي       2
# Name: count, dtype: int64

# %%
merged_df
# Out:
#     char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0     د ب س   S B D        د        ب        س        D        B        S
# 1     س ن ص   X N S        س        ن        ص        S        N        X
# 2     ق ح ل   L J G        ق        ح        ل        G        J        L
# 3     ل ب ل   L B L        ل        ب        ل        L        B        L
# 4     أ أ أ   A A A        أ        أ        أ        A        A        A
# ..      ...     ...      ...      ...      ...      ...      ...      ...
# 240   ر ه ق   G H R        ر        ه        ق        R        H        G
# 241   ر ر ق   G R R        ر        ر        ق        R        R        G
# 242   ر ن د   D N R        ر        ن        د        R        N        D
# 243   ب أ ي   V A B        ب        أ        ي        B        A        V
# 244   ر ق د   D G R        ر        ق        د        R        G        D
#
#      plate_no   price class
# 0           1  500000   NaN
# 1          10   17000   NaN
# 2          40   12500   NaN
# 3          91   12500   NaN
# 4        2116    8000   NaN
# ..        ...     ...   ...
# 240      7212    1000   NaN
# 241      9799    2800   NaN
# 242      1515   16500   NaN
# 243      8988    4500   NaN
# 244      5862    1000   NaN
#
# [245 rows x 11 columns]

# %%
merged_df.to_csv('absher.csv', index=False)

# %%
df1.to_csv('data/mazad_1_cleand.csv',index=False)

# %%
df2.to_csv('data/mazad_2_cleand.csv',index=False)
