# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the data

# %%
df = pd.read_csv("data/data_with_features.csv")

# %%
df[df['char_ar'] == "ن ص أ"]
# Out:
# Empty DataFrame
# Columns: [char_ar, char_en, char1_ar, char2_ar, char3_ar, char1_en, char2_en, char3_en, plate_no, price, class, plate_no_length, similar_digits, sepcial_date, saudi_tribes, One Digit, Two Digits (Same), Two Digits (Different), Three Digits (Same), Three Digits (Different), Four Digits (Same), Four Digits (Different), emergency_no, in_order, reversed_order, same_middles_no, plaindromic_no, same_first_last_no, same_two_sides, one_digit_zero, one_digit_one, one_digit_two, one_digit_three, one_digit_four, one_digit_five, one_digit_six, one_digit_seven, one_digit_eight, one_digit_nine, is_triple_letters, is_one_letters, First_Third_Match, is_sequence, Contains_Tribe, contains_special_words, contains_special_cars, connect_12, connect_23, combined_word, word_freq_score, first_name_rank]
# Index: []

# %% [markdown]
# ## 1. Data Profiling:

# %%
df.shape
# Out:
# (3600, 51)

# %%
#pd.set_option('display.max_columns', None)
df
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0      ر ه م   Z H R        ر        ه        م        R        H        Z
# 1      ر ه م   Z H R        ر        ه        م        R        H        Z
# 2      ر ه م   Z H R        ر        ه        م        R        H        Z
# 3      ر أ ن   N A R        ر        أ        ن        R        A        N
# 4      ه ر ب   B R H        ه        ر        ب        H        R        B
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3595   ه م ن   N Z H        ه        م        ن        H        Z        N
# 3596   د ص ع   E X D        د        ص        ع        D        X        E
# 3597   ب ى ى   V V B        ب        ى        ى        B        V        V
# 3598   ر ع ب   B E R        ر        ع        ب        R        E        B
# 3599   ق و ص   X U G        ق        و        ص        G        U        X
#
#       plate_no  price class  plate_no_length  similar_digits  sepcial_date  \
# 0         9777   6500   NaN                4           False         False
# 1         9888   6500   NaN                4           False         False
# 2         9666   6500   NaN                4           False         False
# 3            3  35000   NaN                1            True         False
# 4           22  50000   NaN                2            True         False
# ...        ...    ...   ...              ...             ...           ...
# 3595       203  20000   NaN                3           False         False
# 3596         2  40000   NaN                1            True         False
# 3597       505  50000   NaN                3           False         False
# 3598      3533  15000   NaN                4           False         False
# 3599         6     50   NaN                1            True         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0            False      False              False                   False
# 1            False      False              False                   False
# 2            False      False              False                   False
# 3            False       True              False                   False
# 4            False      False               True                   False
# ...            ...        ...                ...                     ...
# 3595         False      False              False                   False
# 3596         False       True              False                   False
# 3597          True      False              False                   False
# 3598         False      False              False                   False
# 3599         False       True              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 3                   False                     False               False
# 4                   False                     False               False
# ...                   ...                       ...                 ...
# 3595                False                      True               False
# 3596                False                     False               False
# 3597                False                     False               False
# 3598                False                     False               False
# 3599                False                     False               False
#
#       Four Digits (Different)  emergency_no  in_order  reversed_order  \
# 0                       False         False     False           False
# 1                       False         False     False           False
# 2                       False         False     False           False
# 3                       False         False      True            True
# 4                       False         False     False           False
# ...                       ...           ...       ...             ...
# 3595                    False         False     False           False
# 3596                    False         False      True            True
# 3597                    False         False     False           False
# 3598                    False         False     False           False
# 3599                    False         False      True            True
#
#       same_middles_no  plaindromic_no  same_first_last_no  same_two_sides  \
# 0                True           False               False            True
# 1                True           False               False            True
# 2                True           False               False            True
# 3               False           False               False           False
# 4               False            True                True            True
# ...               ...             ...                 ...             ...
# 3595            False           False               False           False
# 3596            False           False               False           False
# 3597            False            True                True           False
# 3598            False           False                True            True
# 3599            False           False               False           False
#
#       one_digit_zero  one_digit_one  one_digit_two  one_digit_three  \
# 0              False          False          False            False
# 1              False          False          False            False
# 2              False          False          False            False
# 3              False          False          False             True
# 4              False          False          False            False
# ...              ...            ...            ...              ...
# 3595           False          False          False            False
# 3596           False          False           True            False
# 3597           False          False          False            False
# 3598           False          False          False            False
# 3599           False          False          False            False
#
#       one_digit_four  one_digit_five  one_digit_six  one_digit_seven  \
# 0              False           False          False            False
# 1              False           False          False            False
# 2              False           False          False            False
# 3              False           False          False            False
# 4              False           False          False            False
# ...              ...             ...            ...              ...
# 3595           False           False          False            False
# 3596           False           False          False            False
# 3597           False           False          False            False
# 3598           False           False          False            False
# 3599           False           False           True            False
#
#       one_digit_eight  one_digit_nine  is_triple_letters  is_one_letters  \
# 0               False           False              False           False
# 1               False           False              False           False
# 2               False           False              False           False
# 3               False           False              False           False
# 4               False           False              False           False
# ...               ...             ...                ...             ...
# 3595            False           False              False           False
# 3596            False           False              False           False
# 3597            False           False              False           False
# 3598            False           False              False           False
# 3599            False           False              False           False
#
#       First_Third_Match  is_sequence  Contains_Tribe  contains_special_words  \
# 0                 False        False           False                   False
# 1                 False        False           False                   False
# 2                 False        False           False                   False
# 3                 False        False           False                   False
# 4                 False        False           False                   False
# ...                 ...          ...             ...                     ...
# 3595              False        False           False                   False
# 3596              False        False           False                   False
# 3597              False        False           False                   False
# 3598              False        False           False                   False
# 3599              False        False           False                   False
#
#       contains_special_cars  connect_12  connect_23 combined_word  \
# 0                     False           0           1           رهم
# 1                     False           0           1           رهم
# 2                     False           0           1           رهم
# 3                     False           0           0           رأن
# 4                     False           1           0           هرب
# ...                     ...         ...         ...           ...
# 3595                  False           1           1           همن
# 3596                  False           0           1           دصع
# 3597                  False           1           1           بىى
# 3598                  False           0           1           رعب
# 3599                  False           1           0           قوص
#
#       word_freq_score  first_name_rank
# 0            8.757550         0.000000
# 1            8.757550         0.000000
# 2            8.757550         0.000000
# 3           44.089733        80.505952
# 4           62.381363         0.000000
# ...               ...              ...
# 3595        13.201035         0.000000
# 3596         0.000000         0.000000
# 3597        14.020708        10.379464
# 3598        72.088007        37.388393
# 3599        15.444349         0.000000
#
# [3600 rows x 51 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3600 entries, 0 to 3599
# Data columns (total 51 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   char_ar                   3600 non-null   object
#  1   char_en                   3600 non-null   object
#  2   char1_ar                  3600 non-null   object
#  3   char2_ar                  3595 non-null   object
#  4   char3_ar                  3587 non-null   object
#  5   char1_en                  3600 non-null   object
#  6   char2_en                  3595 non-null   object
#  7   char3_en                  3587 non-null   object
#  8   plate_no                  3600 non-null   int64
#  9   price                     3600 non-null   int64
#  10  class                     35 non-null     object
#  11  plate_no_length           3600 non-null   int64
#  12  similar_digits            3600 non-null   bool
#  13  sepcial_date              3600 non-null   bool
#  14  saudi_tribes              3600 non-null   bool
#  15  One Digit                 3600 non-null   bool
#  16  Two Digits (Same)         3600 non-null   bool
#  17  Two Digits (Different)    3600 non-null   bool
#  18  Three Digits (Same)       3600 non-null   bool
#  19  Three Digits (Different)  3600 non-null   bool
#  20  Four Digits (Same)        3600 non-null   bool
#  21  Four Digits (Different)   3600 non-null   bool
#  22  emergency_no              3600 non-null   bool
#  23  in_order                  3600 non-null   bool
#  24  reversed_order            3600 non-null   bool
#  25  same_middles_no           3600 non-null   bool
#  26  plaindromic_no            3600 non-null   bool
#  27  same_first_last_no        3600 non-null   bool
#  28  same_two_sides            3600 non-null   bool
#  29  one_digit_zero            3600 non-null   bool
#  30  one_digit_one             3600 non-null   bool
#  31  one_digit_two             3600 non-null   bool
#  32  one_digit_three           3600 non-null   bool
#  33  one_digit_four            3600 non-null   bool
#  34  one_digit_five            3600 non-null   bool
#  35  one_digit_six             3600 non-null   bool
#  36  one_digit_seven           3600 non-null   bool
#  37  one_digit_eight           3600 non-null   bool
#  38  one_digit_nine            3600 non-null   bool
#  39  is_triple_letters         3600 non-null   bool
#  40  is_one_letters            3600 non-null   bool
#  41  First_Third_Match         3600 non-null   bool
#  42  is_sequence               3600 non-null   bool
#  43  Contains_Tribe            3600 non-null   bool
#  44  contains_special_words    3600 non-null   bool
#  45  contains_special_cars     3600 non-null   bool
#  46  connect_12                3600 non-null   int64
#  47  connect_23                3600 non-null   int64
#  48  combined_word             3587 non-null   object
#  49  word_freq_score           3600 non-null   float64
#  50  first_name_rank           3600 non-null   float64
# dtypes: bool(34), float64(2), int64(5), object(10)
# memory usage: 597.8+ KB

# %%
df[df['price'] > 500000][['char_ar','plate_no','price']].sort_values('price')
# Out:
#      char_ar  plate_no         price
# 1214   د أ ى         1        550000
# 1371   س م ن         2        600000
# 3149   ب ر س         1        600000
# 1617   و ر د       771        610000
# 904    ر ن أ      3000        610000
# 1974   ك ى ط         6        650000
# 2559   د ح ط       999        700000
# 1258   ق ق ك         1        700000
# 3458   و ر ب         3        700000
# 1531   د ن ه         1        700000
# 2733   ب أ ل         1        700000
# 2380   ب س س         1        730000
# 1159   ن م ى         1        750000
# 2401   و ط م       666        900500
# 2409   ن أ ر       393       1000000
# 1385   ط ى ى         1       1000000
# 3227   د ح ق        34       1000000
# 294    ح ك ن      1110       1000000
# 3587   أ ن ق         3       1000000
# 1269   س ك ر         9       1000000
# 1370   ر م ح       305       1000000
# 372    و أ ط        12       1000000
# 373    ق ى م         1       1000000
# 2070   د م د      8888       1010101
# 1312   م ك ه        10       1100000
# 3293   ه ب أ         1       1100000
# 473    أ أ أ         0       2000000
# 2399       س         0       2500000
# 385    س ن ر         1       2500000
# 536    ب و ق      7373       4000000
# 1082   ل ح ن         7       4700000
# 2166   ن ل س       555       5000000
# 711    ق ح ط       505       5000000
# 516    ى ق ح       979       5250000
# 1460   ب ب ى         1       7000000
# 2398       س         0     205000000
# 2420   د ح ط       999     310443054
# 2627   ب و ب       707     552318009
# 2452   د ح ط       999    2484543484
# 2451   د ح ط       999    7643844543
# 2462   د ح ط       999  108446043404
# 2656   ه ك ن        80  999999999999

# %% [markdown]
# ### Data Quality Checks

# %%
df[(df['price'] < 500000) & (df['price'] > 400000)][['char_ar','plate_no','price']].sort_values('price').head(60)
# Out:
#      char_ar  plate_no   price
# 919    و ي و         1  420000
# 1504   د ل ع       666  450000
# 1102   ى ح ل         1  480000
# 1202   ح ك و         1  490000

# %%
df[(df['price'] < 400000) & (df['price'] > 300000)][['char_ar','plate_no','price']].sort_values('price').head(60)
# Out:
#      char_ar  plate_no   price
# 620    ط ك ص         1  320000
# 1536   ب ص ب         1  330000
# 416    ر ح ل      2030  350000
# 440    ع ر ل         1  350000
# 577    م س و         3  350000
# 1166   ع ل ه         1  350000
# 1392   ر ح ل      2030  350000
# 3257   ص ح أ         2  350000
# 1408   ك ى ى         8  360000
# 1116   و د ر         1  370000

# %%
df[(df['price'] < 300000) & (df['price'] > 200000)][['char_ar','plate_no','price']].sort_values('price').head(60)
# Out:
#      char_ar  plate_no   price
# 474    ح ح ح        16  220000
# 156    س م ى         9  250000
# 510    ب س س        11  250000
# 1383   ط ل س         6  250000
# 1781   س ح ب        10  250000
# 3029   ط ق س         3  250000

# %%
df[(df['price'] < 200000) & (df['price'] > 100000)][['char_ar','plate_no','price']].sort_values('price').head(60)
# Out:
#      char_ar  plate_no   price
# 342    ص م ن         6  102000
# 532    و ك س         2  105000
# 2495   د و ن         1  110000
# 116    ص ى ب         2  110000
# 1353   ه ه ه       151  110000
# 1404   ص ر ل         3  110000
# 1225   ن ط ى         6  110000
# 2431   ه د د         2  110000
# 28     د ط د         2  115000
# 692    ص ع د         9  115000
# 557    ح ر ع         8  115000
# 2530   ب ل ل         1  115000
# 961    د ل ر         2  120000
# 1230   ك س م         3  120000
# 1321   ح ع ح         7  120000
# 1338   ى ب ب         8  120000
# 3151   ه ق أ         5  120000
# 1114   د ل و         2  120000
# 960    ع م و         3  120000
# 1378   و أ ه         9  120000
# 694    ر ص ل         2  120000
# 284    ر ق ع       666  120000
# 99     ع ع ح         5  120000
# 443    ع س س         2  125000
# 894    س ن د        50  125000
# 75     ى ع ل         4  125000
# 410    ل ص ص         3  130000
# 2606   ل ط و         3  130000
# 339    م ر ه        11  130000
# 1271   ى ن د         5  130000
# 1774   أ ص س         1  130000
# 1431   م ق ب         2  130000
# 1076   د ى ل         1  130000
# 626    ن م س         9  135000
# 315    ر ص ل         2  135000
# 1194   ب ن ه         5  140000
# 1395   ى ن ح        40  140000
# 3002   ر ك ك         3  140000
# 1167   ب ى ى         7  145000
# 1971   و م ح         5  150000
# 2050   م ح م        15  150000
# 1948   ع ه د       203  150000
# 2456   أ س أ      7777  150000
# 3129   س و ح         4  150000
# 1350   س و ط         6  150000
# 1303   ك ر ر         9  150000
# 1280   ن ل ص         3  150000
# 1278   و ى د         2  150000
# 3185   و م ر         7  150000
# 1203   ى ط ى         2  150000
# 1189   أ ع ى         5  150000
# 402    س أ ر       999  150000
# 1391   ع ر ن        20  150000
# 1343   ه ن م         9  155000
# 388    ن ح ل         3  155000
# 1305   ع ق م         2  160000
# 963    ل و أ        77  160000
# 672    ق ق ق        38  170000
# 2633   م م ب         3  170000
# 1226   م م ب         3  170000

# %%
df[(df['price'] < 100000) & (df['price'] > 70000)][['char_ar','plate_no','price']].sort_values('price').head(60)
# Out:
#      char_ar  plate_no  price
# 1598   أ أ أ      7777  72000
# 628    ص ل م         9  73000
# 638    ن ق ب         5  75000
# 396    د ر ط         3  75000
# 259    ر ن أ       121  75000
# 1836   ى أ م       919  75000
# 215    ل ه ط         6  75000
# 2918   ح ق ل         9  75000
# 1213   ع و ق         4  75000
# 3313   ط ط ص         7  75000
# 48     ك ح أ         7  75000
# 175    و س أ         9  75000
# 880    م ك ع         2  76000
# 1364   ح و ع         4  79000
# 1288   د ط ب         8  79000
# 1219   ب و ح        80  80000
# 1215   م ط ل         4  80000
# 1393   ص س ك         7  80000
# 3454   ح أ ب        15  80000
# 1080   س م أ         1  80000
# 1298   و ح ه       666  80000
# 815    د د و         2  80000
# 1618   ن ص ر       375  80000
# 1624   د د د       511  80000
# 3465   س م ن        69  80000
# 1352   س ص ل         8  80000
# 1351   م ر ق        11  80000
# 2201   ك س م         3  80000
# 457    س ه م        79  80000
# 381    أ س د       188  80000
# 140    د ق ر         5  80000
# 3412   ط س ط         5  80000
# 257    ب ه ه      7777  80000
# 595    س ه ل        22  80000
# 3319   ح أ ر        99  80000
# 2558   ع د ل         2  81000
# 1357   س ك ق         6  85000
# 3082   و أ و        18  85000
# 1922   س ع د         2  85000
# 2837   ر ه ح         2  85000
# 2527   ك ن م         7  85000
# 2511   ر ه ح         2  85000
# 2214   ط ح و         3  85000
# 3047   و ح ه         4  85000
# 1947   ح ط ى      8149  85000
# 13     أ م ل         2  85000
# 151    ه ب ط         9  85000
# 155    ه ق و         4  85000
# 173    ر ط ر         3  85000
# 174    س أ ق         4  85000
# 265    و ح ق         2  85000
# 630    س ه م       700  85000
# 591    د ب م         3  85000
# 460    م ن ى        85  85000
# 1285   ص ك ل         5  87000
# 1317   ى ح ع         9  88000
# 467    ى ن د         2  90000
# 3421   ح ط ن         8  90000
# 142    ل ط و         3  90000
# 3318   ط س ط         5  90000

# %%
df[(df['price'] < 70000) & (df['price'] > 50000)][['char_ar','plate_no','price']].sort_values('price').head(60)
# Out:
#      char_ar  plate_no  price
# 947    ع س ط         6  51000
# 2793   و ن ر         7  52000
# 851    ع و ر         8  52000
# 778    ه ع ر         7  53500
# 2791   س ح و         7  55000
# 2020   ن ك س       555  55000
# 479    ط ر ب        59  55000
# 543    أ ى ط      6666  55000
# 1662   أ ل و         2  55000
# 605    ح ك ر         7  55000
# 1640   و ل د         3  55000
# 1482   س ر ص         5  55000
# 1249   و ر د        25  55000
# 737    م و ى       999  55000
# 1132   ص ح ر       666  55000
# 362    ل م أ        80  55000
# 343    ص ح ر       666  55000
# 9      ص ى ن        11  55000
# 2279   د ح ط       999  55000
# 3464   ق ح ك         5  55000
# 3294   ح ق م         4  55000
# 2987   ه ن ع         8  55000
# 244    م و ن       100  55000
# 3060   س ن ط         8  55000
# 3057   س ن ط         8  55000
# 2921   ح م د      8099  55555
# 85     و ر د        25  58000
# 477    ر و ن        33  58000
# 112    ع و ح         7  58000
# 1239   ح ب و        10  59000
# 326    ك ه ع         4  59500
# 1097   ق ل ب       966  60000
# 1128   ق ه ب         7  60000
# 2826   ل م أ         4  60000
# 3366   و م أ        33  60000
# 3261   ر ل ط         4  60000
# 1304   ه ه ر        30  60000
# 1313   ر ع ب      3000  60000
# 2228   ك ن ر         4  60000
# 3165   ق و ى       172  60000
# 3158   ق ى ك         6  60000
# 2860   ق م ر       464  60000
# 3070   ه و و        90  60000
# 1970   د س م        14  60000
# 2991   ل م ق         7  60000
# 2602   ه ن أ        33  60000
# 2219   ل ل ع       505  60000
# 2249   س ل م        94  60000
# 1891   ل ه س        80  60000
# 793    ن ه ر        80  60000
# 409    ح و ب      3333  60000
# 45     أ أ ح      5555  60000
# 50     أ ب م        20  60000
# 154    أ و د        77  60000
# 242    ب ل و        77  60000
# 270    س ه م       707  60000
# 323    د د ن       555  60000
# 330    م و ل        90  60000
# 336    ق ه ب         7  60000
# 353    ح و أ       911  60000

# %%
df[df['Four Digits (Same)'] & (df['price'] > 17000)].sort_values('price').shape
# Out:
# (48, 51)

# %%
df[(df['Four Digits (Different)']) & (df['price'] > 12000)][['char_ar','plate_no','price']].shape
# Out:
# (26, 3)

# %%
df[(df['Three Digits (Different)']==True) & (df['price'] < 5000) ][['char_ar','plate_no','price']].sort_values('price').shape
# Out:
# (67, 3)

# %%
df[(df['Three Digits (Same)'] == True) & (df['price'] >=20000) & (df['price'] <= 500000)][['char_ar','plate_no','price']].sort_values('price').shape
# Out:
# (117, 3)

# %% [markdown]
# - Filter by one digit plates

# %%
df[(df['same_two_sides']) & df['Three Digits (Different)']==False][['char_ar','plate_no','price']].sort_values('price').head(150).tail(50)
# Out:
#      char_ar  plate_no  price
# 1486   د ر ى      6146   2500
# 514    د ن ى      2072   2500
# 1527   ر ب ع      4867   2699
# 551    ح ك ح      4464   2800
# 1917   ر ه ط       309   2800
# 985    ر ر ق      9799   2800
# 2251   م س س       309   2900
# 207    ح أ د      1441   3000
# 1039   و ه م       633   3000
# 585    ح م د      8733   3000
# 2715   ح م د      5624   3000
# 2001   ب ه ه      1881   3000
# 471    ح ب ك      4428   3000
# 1968   ب م م      8882   3000
# 2051   ب م ب      4447   3000
# 1681   ى و ق       318   3000
# 2107   س ق ل       908   3000
# 2635   د د ط      2011   3000
# 2062   ر د ك      4292   3000
# 496    ب ر أ      4002   3000
# 2954   أ ك د      1117   3000
# 2077   ح ن س       732   3000
# 2082   ح ر أ       460   3000
# 379    ح ب ق      9444   3000
# 148    د ص د      6966   3000
# 383    ح ن و      7591   3000
# 506    ب ك ل      8887   3000
# 2141   م م ع       926   3000
# 537    ر ن ك      2111   3000
# 324    و ه ق       457   3000
# 2386   ب د د      2424   3000
# 719    ح ى ن      5155   3000
# 898    د ص ي       822   3000
# 722    ر ن و      9246   3000
# 2356   ك ب د       291   3000
# 2188   ر ر ح      3633   3000
# 3074   ب د ب      8952   3000
# 2327   أ م ب       351   3000
# 1862   ر ن و      2998   3000
# 764    ح ن ه      9599   3000
# 768    ر ح ب       334   3000
# 769    ر ن د      4559   3000
# 773    و ك أ       837   3000
# 357    ح ر س      9418   3000
# 874    و ه ص       108   3000
# 1340   ب س م      2644   3000
# 869    ب ع ن      4555   3000
# 865    ر ط ر      7676   3000
# 860    ح م ر      3338   3000
# 1852   م د ل       698   3000

# %%
df['char_en'][2955]
# Out:
# 'A'

# %% [markdown]
# #### 1. Reliability:

# %%
# Data collected from the Saudi plate market:
# - https://mazad.absher.sa/
# - https://lu7ah.com/
# - https://www.raqmvip.com/
# - https://www.lohatk.sa/
# - https://www.mstaml.com/sa/market/%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9/%D9%84%D9%88%D8%AD%D8%A7%D8%AA-%D8%B3%D9%8A%D8%A7%D8%B1%D8%A7%D8%AA-%D9%85%D9%85%D9%8A%D8%B2%D8%A9?location=30&type=4.47

# %% [markdown]
# #### 2. Timeliness:

# %%
# up to date

# %% [markdown]
# #### 3. Consistency:

# %%
# it's consistenc

# %% [markdown]
# #### 4. Relevance:

# %%
# sample matching our goal

# %% [markdown]
# #### 5. Uniqueness:

# %%
# Duplicated plate with same price 
df.duplicated().sum()
# Out:
# 91

# %%
# Deleate duplicated
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(['char1_ar','char2_ar','char3_ar','char1_en','char2_en','char3_en','plate_no','price']).sum()
# Out:
# 0

# %%
df.duplicated(['char1_ar','char2_ar','char3_ar','char1_en','char2_en','char3_en','plate_no']).sum()
# Out:
# 215

# %%
# Check dublicated with same plate but with different price
# And take the highest price
df[df.sort_values(['price']).duplicated(['char1_ar', 'char2_ar', 'char3_ar', 'char1_en', 'char2_en', 'char3_en', 'plate_no'],keep='first')]
# Out:
# C:\Users\hamad\AppData\Local\Temp\ipykernel_40468\3628687061.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.sort_values(['price']).duplicated(['char1_ar', 'char2_ar', 'char3_ar', 'char1_en', 'char2_en', 'char3_en', 'plate_no'],keep='first')]
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0      ر ه م   Z H R        ر        ه        م        R        H        Z
# 1      ر ه م   Z H R        ر        ه        م        R        H        Z
# 3      ر أ ن   N A R        ر        أ        ن        R        A        N
# 6      أ ر ب   B R A        أ        ر        ب        A        R        B
# 22     ر ع د   D E R        ر        ع        د        R        E        D
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3514   ب ط ر   R T B        ب        ط        ر        B        T        R
# 3519   ب ق و   U G B        ب        ق        و        B        G        U
# 3520   م ع أ   A E Z        م        ع        أ        Z        E        A
# 3521   و س ه   H S U        و        س        ه        U        S        H
# 3533   ه و و   U U H        ه        و        و        H        U        U
#
#       plate_no  price class  plate_no_length  similar_digits  sepcial_date  \
# 0         9777   6500   NaN                4           False         False
# 1         9888   6500   NaN                4           False         False
# 3            3  35000   NaN                1            True         False
# 6           75  15500   NaN                2           False         False
# 22        3327  10000   NaN                4           False         False
# ...        ...    ...   ...              ...             ...           ...
# 3514      9007  15000   NaN                4           False         False
# 3519      9494  20000   NaN                4           False         False
# 3520        71  25000   NaN                2           False         False
# 3521       212  15000   NaN                3           False         False
# 3533        19  25000   NaN                2           False         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0            False      False              False                   False
# 1            False      False              False                   False
# 3            False       True              False                   False
# 6            False      False              False                    True
# 22           False      False              False                   False
# ...            ...        ...                ...                     ...
# 3514         False      False              False                   False
# 3519         False      False              False                   False
# 3520         False      False              False                    True
# 3521         False      False              False                   False
# 3533         False      False              False                    True
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                   False                     False               False
# 1                   False                     False               False
# 3                   False                     False               False
# 6                   False                     False               False
# 22                  False                     False               False
# ...                   ...                       ...                 ...
# 3514                False                     False               False
# 3519                False                     False               False
# 3520                False                     False               False
# 3521                False                     False               False
# 3533                False                     False               False
#
#       Four Digits (Different)  emergency_no  in_order  reversed_order  \
# 0                       False         False     False           False
# 1                       False         False     False           False
# 3                       False         False      True            True
# 6                       False         False     False           False
# 22                      False         False     False           False
# ...                       ...           ...       ...             ...
# 3514                    False         False     False           False
# 3519                    False         False     False           False
# 3520                    False         False     False           False
# 3521                    False         False     False           False
# 3533                    False         False     False           False
#
#       same_middles_no  plaindromic_no  same_first_last_no  same_two_sides  \
# 0                True           False               False            True
# 1                True           False               False            True
# 3               False           False               False           False
# 6               False           False               False           False
# 22              False           False               False           False
# ...               ...             ...                 ...             ...
# 3514             True           False               False           False
# 3519            False           False               False           False
# 3520            False           False               False           False
# 3521            False            True                True           False
# 3533            False           False               False           False
#
#       one_digit_zero  one_digit_one  one_digit_two  one_digit_three  \
# 0              False          False          False            False
# 1              False          False          False            False
# 3              False          False          False             True
# 6              False          False          False            False
# 22             False          False          False            False
# ...              ...            ...            ...              ...
# 3514           False          False          False            False
# 3519           False          False          False            False
# 3520           False          False          False            False
# 3521           False          False          False            False
# 3533           False          False          False            False
#
#       one_digit_four  one_digit_five  one_digit_six  one_digit_seven  \
# 0              False           False          False            False
# 1              False           False          False            False
# 3              False           False          False            False
# 6              False           False          False            False
# 22             False           False          False            False
# ...              ...             ...            ...              ...
# 3514           False           False          False            False
# 3519           False           False          False            False
# 3520           False           False          False            False
# 3521           False           False          False            False
# 3533           False           False          False            False
#
#       one_digit_eight  one_digit_nine  is_triple_letters  is_one_letters  \
# 0               False           False              False           False
# 1               False           False              False           False
# 3               False           False              False           False
# 6               False           False              False           False
# 22              False           False              False           False
# ...               ...             ...                ...             ...
# 3514            False           False              False           False
# 3519            False           False              False           False
# 3520            False           False              False           False
# 3521            False           False              False           False
# 3533            False           False              False           False
#
#       First_Third_Match  is_sequence  Contains_Tribe  contains_special_words  \
# 0                 False        False           False                   False
# 1                 False        False           False                   False
# 3                 False        False           False                   False
# 6                 False        False           False                   False
# 22                False        False           False                   False
# ...                 ...          ...             ...                     ...
# 3514              False        False           False                   False
# 3519              False        False           False                   False
# 3520              False        False           False                   False
# 3521              False        False           False                   False
# 3533              False        False           False                   False
#
#       contains_special_cars  connect_12  connect_23 combined_word  \
# 0                     False           0           1           رهم
# 1                     False           0           1           رهم
# 3                     False           0           0           رأن
# 6                     False           0           0           أرب
# 22                    False           0           1           رعد
# ...                     ...         ...         ...           ...
# 3514                  False           1           1           بطر
# 3519                  False           1           1           بقو
# 3520                  False           1           1           معأ
# 3521                  False           0           1           وسه
# 3533                  False           1           0           هوو
#
#       word_freq_score  first_name_rank
# 0            8.757550         0.000000
# 1            8.757550         0.000000
# 3           44.089733        80.505952
# 6           33.951682        15.327381
# 22          64.710958        97.619048
# ...               ...              ...
# 3514        10.914582        36.495536
# 3519        19.262295         0.000000
# 3520        89.689387        62.872024
# 3521         0.000000         0.000000
# 3533        16.781708         0.000000
#
# [215 rows x 51 columns]

# %%
df.shape
# Out:
# (3509, 51)

# %% [markdown]
# #### 6. Completeness:

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# class                       3474
# char3_ar                      13
# combined_word                 13
# char3_en                      13
# char2_ar                       5
# char2_en                       5
# char_ar                        0
# one_digit_five                 0
# one_digit_eight                0
# one_digit_seven                0
# one_digit_six                  0
# one_digit_two                  0
# one_digit_four                 0
# one_digit_three                0
# is_triple_letters              0
# one_digit_one                  0
# one_digit_nine                 0
# is_sequence                    0
# is_one_letters                 0
# First_Third_Match              0
# same_two_sides                 0
# Contains_Tribe                 0
# contains_special_words         0
# contains_special_cars          0
# connect_12                     0
# connect_23                     0
# word_freq_score                0
# one_digit_zero                 0
# same_middles_no                0
# same_first_last_no             0
# plaindromic_no                 0
# char1_ar                       0
# char1_en                       0
# plate_no                       0
# price                          0
# plate_no_length                0
# similar_digits                 0
# sepcial_date                   0
# saudi_tribes                   0
# One Digit                      0
# Two Digits (Same)              0
# Two Digits (Different)         0
# Three Digits (Same)            0
# Three Digits (Different)       0
# Four Digits (Same)             0
# Four Digits (Different)        0
# emergency_no                   0
# in_order                       0
# reversed_order                 0
# char_en                        0
# first_name_rank                0
# dtype: int64

# %% [markdown]
# #### 7. Check Accuracy:

# %%
# All columns all same datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3509 entries, 0 to 3599
# Data columns (total 51 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   char_ar                   3509 non-null   object
#  1   char_en                   3509 non-null   object
#  2   char1_ar                  3509 non-null   object
#  3   char2_ar                  3504 non-null   object
#  4   char3_ar                  3496 non-null   object
#  5   char1_en                  3509 non-null   object
#  6   char2_en                  3504 non-null   object
#  7   char3_en                  3496 non-null   object
#  8   plate_no                  3509 non-null   int64
#  9   price                     3509 non-null   int64
#  10  class                     35 non-null     object
#  11  plate_no_length           3509 non-null   int64
#  12  similar_digits            3509 non-null   bool
#  13  sepcial_date              3509 non-null   bool
#  14  saudi_tribes              3509 non-null   bool
#  15  One Digit                 3509 non-null   bool
#  16  Two Digits (Same)         3509 non-null   bool
#  17  Two Digits (Different)    3509 non-null   bool
#  18  Three Digits (Same)       3509 non-null   bool
#  19  Three Digits (Different)  3509 non-null   bool
#  20  Four Digits (Same)        3509 non-null   bool
#  21  Four Digits (Different)   3509 non-null   bool
#  22  emergency_no              3509 non-null   bool
#  23  in_order                  3509 non-null   bool
#  24  reversed_order            3509 non-null   bool
#  25  same_middles_no           3509 non-null   bool
#  26  plaindromic_no            3509 non-null   bool
#  27  same_first_last_no        3509 non-null   bool
#  28  same_two_sides            3509 non-null   bool
#  29  one_digit_zero            3509 non-null   bool
#  30  one_digit_one             3509 non-null   bool
#  31  one_digit_two             3509 non-null   bool
#  32  one_digit_three           3509 non-null   bool
#  33  one_digit_four            3509 non-null   bool
#  34  one_digit_five            3509 non-null   bool
#  35  one_digit_six             3509 non-null   bool
#  36  one_digit_seven           3509 non-null   bool
#  37  one_digit_eight           3509 non-null   bool
#  38  one_digit_nine            3509 non-null   bool
#  39  is_triple_letters         3509 non-null   bool
#  40  is_one_letters            3509 non-null   bool
#  41  First_Third_Match         3509 non-null   bool
#  42  is_sequence               3509 non-null   bool
#  43  Contains_Tribe            3509 non-null   bool
#  44  contains_special_words    3509 non-null   bool
#  45  contains_special_cars     3509 non-null   bool
#  46  connect_12                3509 non-null   int64
#  47  connect_23                3509 non-null   int64
#  48  combined_word             3496 non-null   object
#  49  word_freq_score           3509 non-null   float64
#  50  first_name_rank           3509 non-null   float64
# dtypes: bool(34), float64(2), int64(5), object(10)
# memory usage: 610.0+ KB

# %% [markdown]
# ## 2. Data Cleaning:

# %%
# Drop all plate withe digit 0
df = df[df['plate_no'] != 0]

# %%
# Drop all plate withe price > 1000
df = df[df['price'] >= 1000]

# %%
# Drop all plate withe price > 7,0000000
df = df[df['price'] <= 5000000]

# %%
# get the outliers value indexes to drop it all 

outliers_plates = {
    # From 500K to 2M
    771:'و ر د',
    3000:'ر ن أ',
    999:'د ح ط',
    666:'و ط م',
    393:'ن أ ر',
    34:'د ح ق',
    1110:'ح ك ن',
    12:'و أ ط',
    8888:'د م د',
    7373:'ب و ق',
    555:'ن ل س',
    # From 100K - 200K
    20:'ع ر ن',
    40:'ى ن ح',
    # From 70K - 100K
    8149:'ح ط ى',
    1897:'ب ط ل',

    # From 50K - 70K
    7703:'ر ب ى',
    8099:'ح م د',
    5817:'ب د ر',
    5252:'ح ل م',
    1223:'ر ق ه',
    602:'ع ع س',
    5115:'أ ص م',
    7705:'ح ر ب',
    3614:'ح ر ب',
    9777:'ح ه ع',
    166:'ه ح ل',
    4321:'ب ي م',
    3509:'ح ر ب',
    1182:'أ ن ص',
    9998:'د و ط',
    2013:'ح ى أ',
    3614:'ح ر ب',
    3000:'ر ن ق',
    5353:'ح ل ك',
    8001:'ا ه ن',
    2719:'ح م د',
    13:'م ب ص',
    322:'ع ر ب',
    111:'د ع م',
    41:'ع ل م',
    4444:'ن و ح',
    342:'م ك ه',


    # One digit outlier
    7:'ل ل ل',
    4:'ا و ك',
    8:'و ه ب',
    9:'ن و ح',
    9:'ن د ا',
    8:'س ب ب',
    3:'ه ك ص',
    9:'ح ب ك',
    8:'ح و ر',
    7:'ع س ل',
    7:'ا ا م',
    9:'ن د أ',
    9:'ن ح و',
    9:'ن و ح',
    9:'ه ك ر',
    5:'ل ن ا',
    3:'ن س ق',
    6:'د ا ل',
    2:'ع ع و',
    6:'م ن ح',
    5:'س ر ب',
    3:'س ر ب',
    1:'ر ب ى',
    8:'ص ع ص',
    4:'و ر د',
    4:'ص ص ع',
    8:'ر ل ر',
    9:'ح ك ك',
    55:'ع س ل',
    88:'ق ب ب',
    77:'ح ر ب',
    11:'ر ك ل',
    88:'ط و ر',
    66:'ن ط ط',
    99:'ع س ل',
    77:'ق ى ع',
    22:'ع ه م',
    77:'ع س ل',
    22:'ق م ر',
    44:'س ن د',
    33:'س س س',
    44:'ن و ح',
    44:'و ك ر',
    44:'ه ب ب',
    99:'ع س ل',
    22:'ط ل ه',
    55:'ب ن ق',
    88:'م ق ن',
    11:'ر ع ب',
    11:'ه ل و',
    55:'ق ح ط',
    11:'ق ط ا',
    66:'س ب ع',
    22:'ك م ر',
    77:'ل ط و',
    66:'ا و ك',
    77:'ح ح ه',
    77:'ا ا ا',
    22:'ه ح ه',
    99:'ى ى ع',
    44:'ى ى ك',
    92:'و م ص',
    52:'ق ب ب',
    85:'أ أ أ',
    16:'ب ط م',
    17:'و ح أ',
    49:'ر ر س',
    41:'و ك ر',
    82:'ع د ع',
    65:'م م ن',
    62:'ل ه ه',
    10:'د ب ب',
    27:'د د ص',
    56:'ل ر ل',
    43:'ك ك ح',
    10:'و أ و',
    85:'أ أ أ',
    10:'س ح ح',
    38:'س ا د',
    13:'ه ل ع',
    58:'و ع و',
    62:'و و س',
    17:'ع ع ب',
    28:'ط ى ى',
    70:'ا ا س',
    93:'ر ع ب',
    79:'ح ق د',
    38:'ص ب ص',
    97:'ه ه و',
    40:'ص ق ر',
    70:'ل ل د',
    25:'ه ه ن',
    94:'ل م ل',
    1111:'ح ر م',
    9999:'ر م ك	',
    555:'ص ب د',
    669:'و ب أ',
    771:'ص س ى',
    633:'و ه م',
    446:'و م ح',
    332:'و م ح',
    334:'ر ح ب',
    433:'ى ى ص',
    977:'و ط س',
    455:'م ك ق',
    844:'ه ل ه',
    700:'أ أ ط',
    330:'و ه ى',
    9277:'ح و ر',
    2777:'ر م ه	',
    443:'ل ك ح',
    244:'ح م و',
    117:'ص م ك',
    288:'ن ص ن',
    9888:'أ ل د',
    441:'و ط و',
    3444:'ر ع ر',
    6111:'ب ق ل',
    855:'ق ى ط',
    8899:'ر ل ق',
    822:'م أ ر',
    9777:'ر ه م',
    1400:'ر ه م',
    330:'د م ع',
    446:'و م ح',
    7222:'د ع ح',
    9888:'ر ه م',
    8988:'د ر ع',
    366:'و د ع',
    4544:'ر ب د',
    855:'ى ب ص',
    533:'ق د أ',
    400:'ع ك ط	',
    211:'ن ح ك',
    299:'و ك ك',
    555:'ص ب د',
    333:'أ د ى',
    999:'د د ط',
    777:'ص ط أ',
    333:'ع د ح',

    60:'م ن ه',
    727:'ى و ى',  

}
outliers_indexes = []
for no,p in outliers_plates.items():
    print(no,p)
    outliers_indexes.append(df[(df['char_ar'] == p) & (df['plate_no'] == no)].index[0])

len(outliers_plates)
# Out:
# 771 ص س ى
# 3000 ر ن ق
# 999 د د ط
# 666 و ط م
# 393 ن أ ر
# 34 د ح ق
# 1110 ح ك ن
# 12 و أ ط
# 8888 د م د
# 7373 ب و ق
# 555 ص ب د
# 20 ع ر ن
# 40 ص ق ر
# 8149 ح ط ى
# 1897 ب ط ل
# 7703 ر ب ى
# 8099 ح م د
# 5817 ب د ر
# 5252 ح ل م
# 1223 ر ق ه
# 602 ع ع س
# 5115 أ ص م
# 7705 ح ر ب
# 3614 ح ر ب
# 9777 ر ه م
# 166 ه ح ل
# 4321 ب ي م
# 3509 ح ر ب
# 1182 ا ن ص
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[183], line 202
#     200 for no,p in outliers_plates.items():
#     201     print(no,p)
# --> 202     outliers_indexes.append(df[(df['char_ar'] == p) & (df['plate_no'] == no)].index[0])
#     204 len(outliers_plates)
#
# File c:\Users\hamad\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5361, in Index.__getitem__(self, key)
#    5358 if is_integer(key) or is_float(key):
#    5359     # GH#44051 exclude bool, which would return a 2d ndarray
#    5360     key = com.cast_scalar_indexer(key, warn_float=True)
# -> 5361     return getitem(key)
#    5363 if isinstance(key, slice):
#    5364     # This case is separated from the conditional above to avoid
#    5365     # pessimization com.is_bool_indexer and ndim checks.
#    5366     result = getitem(key)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
df[(df['price'] < 15000) & (df['price'] > 13000)][['char_ar','plate_no','price']].sort_values('price').head(60)
# Out:
#      char_ar  plate_no  price
# 3231   م ن ه        60  13200
# 1255   ى و ى       727  13500
# 734    ك ه ق        35  13500
# 968    م ن ه        83  13500
# 183    ن ن م       400  13500
# 1822   د ه م       444  13500
# 1627   ع ه م        22  13500
# 733    ب ه ى        76  13500
# 3205   ى ط س        29  13800
# 105    ه ك ق        80  14000
# 279    ق ب ب        51  14000
# 1263   ق ح و       507  14000
# 120    ق ر ح       800  14000
# 2759   ق س ه       525  14000
# 1540   ك س ح        51  14000
# 1328   ل م س        46  14000
# 1730   م ب ص        13  14000
# 1146   م ك ه       342  14000
# 2696   م م ب        92  14000
# 2405   ى د ه       111  14000
# 276    ى ك ح        96  14000
# 1021   ن س ر       959  14000
# 993    ن س ه        35  14000
# 2782   ى د ع        75  14000
# 185    و ر س        86  14000
# 2677   ن و ح      4444  14000
# 1297   ه د ه       800  14000
# 3491   ه ن و       607  14000
# 456    ن ر ن       906  14000
# 640    أ أ ن       300  14000
# 1941   ع ل م        41  14000
# 3384   ب ه و        97  14000
# 1422   ح ا ا        42  14000
# 3273   ح ا ل      6660  14000
# 1518   ح ن م        14  14000
# 2023   د ع م       111  14000
# 998    د ل ع      4444  14000
# 375    ر ح ط      6662  14000
# 847    ر ك ق      8888  14000
# 293    ع م ك       148  14000
# 845    ر ه ص      7777  14000
# 820    ر و ر      1000  14000
# 1910   ر م ا      3000  14000
# 3333   س ل م       155  14000
# 2459   س ن د       445  14000
# 703    ط ب ر        60  14000
# 2833   ط ل ل       505  14000
# 997    ط ل و       444  14000
# 2079   ع ر ب       322  14000
# 927    ع ر ب       611  14000
# 830    ر و ص      4444  14000
# 1178   ع ى ى       330  14000
# 1023   م ح س       800  14500
# 906    ر أ ع      9000  14500
# 170    ه د ع        19  14500
# 1480   د ل ع       320  14500
# 1382   ق م ه       477  14500
# 1768   ح ق ع        14  14500
# 2378   ع س ل        77  14500

# %% [markdown]
# - Outliers In range 400K to 1M

# %%
# I assumed this is outlier 
df.loc[[1083,2071,536,2167,2402,372,2410,294,3228,905,1618,2560]]
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 1083   ع س ل   L S E        ع        س        ل        E        S        L
# 2071   ط ع ر   R E T        ط        ع        ر        T        E        R
# 536    ب و ق   G U B        ب        و        ق        B        U        G
# 2167   ب ر ق   G R B        ب        ر        ق        B        R        G
# 2402   و ط م   Z T U        و        ط        م        U        T        Z
# 372    و أ ط   T A U        و        أ        ط        U        A        T
# 2410   ى ب س   S B V        ى        ب        س        V        B        S
# 294    ح ك ن   N K J        ح        ك        ن        J        K        N
# 3228   م و ل   L U Z        م        و        ل        Z        U        L
# 905    ب ي د   B V D        ب        ي        د        D        V        B
# 1618   ن ص ر   R X N        ن        ص        ر        N        X        R
# 2560   و د ى   V D U        و        د        ى        U        D        V
#
#       plate_no    price  ... First_Third_Match  is_sequence  Contains_Tribe  \
# 1083       359    15000  ...             False        False           False
# 2071       518    15000  ...             False        False           False
# 536       7373  4000000  ...             False        False           False
# 2167       777    19500  ...             False        False           False
# 2402       666    90500  ...             False        False           False
# 372         12  1000000  ...             False        False           False
# 2410        75    30000  ...             False        False           False
# 294       1110  1000000  ...             False        False           False
# 3228        13    50000  ...             False        False           False
# 905       6000    10000  ...             False        False           False
# 1618       375    80000  ...             False        False           False
# 2560       799     6000  ...             False        False           False
#
#       contains_special_words  contains_special_cars  connect_12  connect_23  \
# 1083                   False                  False           1           1
# 2071                   False                  False           1           1
# 536                    False                  False           1           0
# 2167                   False                  False           1           0
# 2402                   False                  False           0           1
# 372                    False                  False           0           0
# 2410                   False                  False           1           1
# 294                    False                  False           1           1
# 3228                   False                  False           1           0
# 905                    False                  False           1           1
# 1618                   False                  False           1           1
# 2560                   False                  False           0           0
#
#       combined_word  word_freq_score  first_name_rank
# 1083            عسل        82.528041         0.000000
# 2071            طعر         0.000000         0.000000
# 536             بوق        29.896462         0.000000
# 2167            برق        68.075928        92.485119
# 2402            وطم         0.000000         0.000000
# 372             وأط        41.760138         0.000000
# 2410            ىبس        30.284728         0.000000
# 294             حكن         0.000000         0.000000
# 3228            مول        80.802416        48.251488
# 905             بيد         0.000000         0.000000
# 1618            نصر        88.697153        97.470238
# 2560            ودى        87.187230        75.744048
#
# [12 rows x 51 columns]

# %% [markdown]
# - Outliers In range 100K to 500K

# %%
# I assumed this is outlier 
df.loc[[284,1396]]
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 284    ر ق ع   E G R        ر        ق        ع        R        G        E
# 1396   د م م   Z Z D        د        م        م        D        Z        Z
#
#       plate_no   price  ... First_Third_Match  is_sequence  Contains_Tribe  \
# 284        666  120000  ...             False        False           False
# 1396         3  180000  ...             False        False           False
#
#       contains_special_words  contains_special_cars  connect_12  connect_23  \
# 284                    False                  False           0           1
# 1396                   False                  False           0           1
#
#       combined_word  word_freq_score  first_name_rank
# 284             رقع         7.290768              0.0
# 1396            دمم         0.000000              0.0
#
# [2 rows x 51 columns]

# %%
# drop 1083,2071 
#df.drop([1083,2071,536,2167,2402,372,2410,294,905,1618,2560,284,1396,1392],inplace=True)

# %%
# Check dublicated with same plate but with different price
# And take the highest price
# Drop the lowest price 
df = df.loc[df.groupby(['char1_ar', 'char2_ar', 'char3_ar', 'char1_en', 'char2_en', 'char3_en', 
                         'plate_no'])['price'].idxmax()]

# %% [markdown]
# ## 3. Univariate Analysis:

# %%
price_counts = df[df['price'] > 500000]['price'].value_counts().sort_index()
plt.figure(figsize=(20, 6))
price_counts.plot(kind='bar', color='skyblue', edgecolor='black')

plt.xlabel('Price')
plt.ylabel('Frequency') 
plt.title('Frequency of Each Price')

plt.xticks(rotation=90, ha='right') 

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.xticks(ticks=range(0, len(price_counts), max(1, len(price_counts)//10)))

plt.show()

# %%
df[(df['price'] < 200000) & (df['price'] > 100000)][['char_ar','plate_no','price']].sort_values('price').tail(15)
# Out:
#      char_ar  plate_no   price
# 1189   ا ع ى         5  150000
# 1303   ك ر ر         9  150000
# 402    س أ ر       999  150000
# 3129   س و ح         4  150000
# 1948   ع ه د       203  150000
# 1350   س و ط         6  150000
# 1343   ه ن م         9  155000
# 388    ن ح ل         3  155000
# 1305   ع ق م         2  160000
# 963    ل و أ        77  160000
# 672    ق ق ق        38  170000
# 1226   م م ب         3  170000
# 3350   د ن ى         2  180000
# 1396   د م م         3  180000
# 1270   ه ه ل         3  190000

# %% [markdown]
# ## 4. Bivariate/Multivariate Analysis:

# %%
for x in df['plate_no_length'].unique():
    df_figure = df[df['plate_no_length'] == x]  # Filter data for each plate_no_length

    plt.figure(figsize=(20, 6))
    sns.countplot(x=df_figure['price'])

    plt.xlabel("Price")
    plt.ylabel("Count")
    plt.title(f"Price Count Chart for Plate No Length {x}")
    plt.xticks(rotation=90)  # Rotate labels for better readability

    plt.show()

# %%
filtering = df.select_dtypes(include=['number', 'bool'])
corr_matrix = filtering.corr()


plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

plt.title("Heatmap of Feature Correlations")
plt.show()
